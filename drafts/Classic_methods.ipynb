# %% [markdown]
# Just considering the new two datasets, and what we can achieve with simple methods.

# %%
import pandas as pd
import numpy as np
import subprocess as sb
import os
import pickle

import utils

root_folder="/media/kali/1b80f30d-2803-4260-a792-9ae206084252/Code/M30/data/"
data_folder="../data/"

# %%
datasets_di = {}

# %% [markdown]
# ## Subsets for exploration (without unlabelled samples)

# %%
## SUBSET WITHOUT UNLABELLED SAMPLES
## Need to run the corresponding cells in custom_dataset.ipynb otherwise
if (os.path.exists(data_folder+"custom_dataset/A.csv")):
    A = pd.read_csv(data_folder+"custom_dataset/A.csv", index_col=0)
    A.index = A.index.astype(str)
else:
    print("Run notebook custom_dataset.ipynb")
if (os.path.exists(data_folder+"custom_dataset/P.csv") and os.path.exists(data_folder+"custom_dataset/S.csv")):
    P = pd.read_csv(data_folder+"custom_dataset/P.csv", index_col=0)
    S = pd.read_csv(data_folder+"custom_dataset/S.csv", index_col=0)
    S.columns = S.columns.astype(str)
    ## multiply expression values for a same gene in both drug and disease signature
    Known_1 = [[list(A.index)[i], list(A.columns)[j]] for i, j in np.argwhere(A.values==1).tolist()]
    Known_m1 = [[list(A.index)[i], list(A.columns)[j]] for i, j in np.argwhere(A.values==-1).tolist()]
    print("#total negative: %d, #total positive: %d" % (len(Known_m1),len(Known_1)))
    Nknown_1=200 ## majority class
    Nknown_m1=100 ## minority class

    pairs_names = Known_m1[:Nknown_m1]+Known_1[:Nknown_1]
    print("#negative: %d, #positive: %d" % (len(Known_m1[:Nknown_m1]),len(Known_1[:Nknown_1])))
    ## Here, features in S and in P are the same (genes)
    SS = S.loc[S.index][[p[0] for p in pairs_names]]
    PP = P.loc[S.index][[p[1] for p in pairs_names]]
    PP += (-1)**(PP.values<0) ##preserve the sign
    Features = np.multiply(SS,PP)
    Features.columns = ["--".join(p) for p in pairs_names]
    Features = Features.T
else:
    print("Run notebook custom_dataset.ipynb")
Features.head()
# Out:
# #total negative: 174, #total positive: 771
# #negative: 100, #positive: 200
#                        A1CF       A2M      AACS     AADAC  AADAT     AAMDC  \
# 145068--C0032285   0.000000  0.000000  0.000000  0.000000    0.0  0.000000
# 5284373--C0014544  0.006304 -0.002591 -0.000174 -0.002253    0.0 -0.005548
# 54687--C0014544   -0.003060 -0.004392  0.000316 -0.008325    0.0  0.006408
# 2284--C0014544    -0.005802 -0.003929  0.002782  0.016020    0.0  0.009123
# 2519--C0014544    -0.007447  0.007845  0.002025 -0.003146    0.0 -0.002169
#
#                        AAMP      AAR2  AARD      AARS  ...    ZSCAN9  ZSWIM6  \
# 145068--C0032285   0.000000  0.000000   0.0 -0.009582  ...  0.000000     0.0
# 5284373--C0014544 -0.017048 -0.006163   0.0  0.030322  ...  0.000814     0.0
# 54687--C0014544    0.001213 -0.001856   0.0  0.014672  ...  0.009547     0.0
# 2284--C0014544     0.008060 -0.004581   0.0 -0.006278  ... -0.003795     0.0
# 2519--C0014544     0.006753 -0.001677   0.0  0.005590  ... -0.004741     0.0
#
#                      ZSWIM8      ZW10     ZWINT      ZXDC  ZYG11B       ZYX  \
# 145068--C0032285   0.000000  0.000000  0.000000  0.000000     0.0  0.000000
# 5284373--C0014544  0.003978 -0.023151 -0.007352  0.012371     0.0 -0.025708
# 54687--C0014544    0.007889 -0.004885  0.001020  0.014016     0.0  0.011977
# 2284--C0014544     0.001538 -0.009056 -0.001609 -0.003781     0.0 -0.008824
# 2519--C0014544     0.002851 -0.009682  0.011514  0.008756     0.0  0.017358
#
#                       ZZEF1      ZZZ3
# 145068--C0032285   0.000000  0.000000
# 5284373--C0014544 -0.002286  0.012661
# 54687--C0014544   -0.011953 -0.003614
# 2284--C0014544    -0.006532  0.000967
# 2519--C0014544    -0.003349  0.002967
#
# [5 rows x 10811 columns]

# %%
if (os.path.exists(data_folder+"custom_dataset/A.csv")):
    A = pd.read_csv(data_folder+"custom_dataset/A.csv", index_col=0)
    A.index = A.index.astype(str)
    A["Drug"] = list(A.index)
    Associations = A.melt(id_vars=["Drug"], var_name=["Disease"], value_name="Class", value_vars=A.columns[:-1])
    Associations.index = [s+"--"+p for s,p in Associations[["Drug","Disease"]].values.tolist()]
    Associations = Associations[["Class"]].loc[Features.index]
else:
    print("Run notebook custom_dataset.ipynb")
Associations.T
# Out:
#        145068--C0032285  5284373--C0014544  54687--C0014544  2284--C0014544  \
# Class              -1.0               -1.0             -1.0            -1.0
#
#        2519--C0014544  5472--C0014544  2481--C0014544  4075--C0014544  \
# Class            -1.0            -1.0            -1.0            -1.0
#
#        2812--C0014544  2153--C0014544  ...  104865--C0011644  \
# Class            -1.0            -1.0  ...               1.0
#
#        104865--C3714958  126941--C2936783  126941--C0033860  126941--C0149925  \
# Class               1.0               1.0               1.0               1.0
#
#        126941--C0023467  126941--C0003873  13342--C0036220  13342--C0153594  \
# Class               1.0               1.0              1.0              1.0
#
#        4946--C0020538
# Class             1.0
#
# [1 rows x 300 columns]

# %%
Features.to_csv("subset_features_TRANSCRIPT.csv")
Associations.to_csv("subset_associations_TRANSCRIPT.csv")

# %%
## Need to run the corresponding cells in PREDICT method.ipynb otherwise
if (os.path.exists(data_folder+"Features_PREDICT.csv")):
    Features = pd.read_csv(data_folder+"Features_PREDICT.csv", index_col=0).T
else:
    print("Run notebook PREDICT method.ipynb")
if (os.path.exists(data_folder+"Associations_PREDICT.csv")):
    A = pd.read_csv(data_folder+"Associations_PREDICT.csv", index_col=0)
    A.index = A.index.astype(str)
    A["Drug"] = list(A.index)
    
    Known_1 = [[list(A.index)[i], list(A.columns)[j]] for i, j in np.argwhere(A.values==1).tolist()]
    Known_m1 = [[list(A.index)[i], list(A.columns)[j]] for i, j in np.argwhere(A.values==-1).tolist()]
    print("#total negative: %d, #total positive: %d" % (len(Known_m1),len(Known_1)))
    Nknown_1=200 ## majority class
    Nknown_m1=100 ## minority class
    pairs_names = Known_m1[:Nknown_m1]+Known_1[:Nknown_1]
    print("#negative: %d, #positive: %d" % (len(Known_m1[:Nknown_m1]),len(Known_1[:Nknown_1])))
    Features = Features.loc[["--".join(p) for p in pairs_names]]
    
    Associations = A.melt(id_vars=["Drug"], var_name=["Disease"], value_name="Class", value_vars=A.columns[:-1])
    Associations.index = [s+"--"+p for s,p in Associations[["Drug","Disease"]].values.tolist()]
    Associations = Associations[["Class"]].loc[Features.index]
else:
    print("Run notebook PREDICT method.ipynb")
Features.head()
# Out:
# #total negative: 289, #total positive: 8231
# #negative: 100, #positive: 200
#                      signature--disease_phenotype  \
# 65028--C5203670                          0.000000
# 3005573--C0027661                        0.504726
# 3386--C0014544                           0.697923
# 3647--C0014544                           0.644868
# 135410875--CN077967                      0.000000
#
#                      signature--disease_semantic  signature--disease_sequence  \
# 65028--C5203670                              0.0                     0.000000
# 3005573--C0027661                            0.0                     0.000000
# 3386--C0014544                               0.0                     0.040366
# 3647--C0014544                               0.0                     0.040307
# 135410875--CN077967                          0.0                     0.000000
#
#                      signature--disease_signature  signature--disease_go  \
# 65028--C5203670                          0.000000               0.000000
# 3005573--C0027661                        0.000000               0.000000
# 3386--C0014544                           0.960719               0.344097
# 3647--C0014544                           0.964305               0.332425
# 135410875--CN077967                      0.000000               0.000000
#
#                      signature--disease_network  network--disease_phenotype  \
# 65028--C5203670                        0.000000                    0.000000
# 3005573--C0027661                      0.000000                    0.522160
# 3386--C0014544                         0.937041                    0.949993
# 3647--C0014544                         0.931771                    0.902558
# 135410875--CN077967                    0.000000                    0.000000
#
#                      network--disease_semantic  network--disease_sequence  \
# 65028--C5203670                            0.0                   0.000000
# 3005573--C0027661                          0.0                   0.000000
# 3386--C0014544                             0.0                   0.056064
# 3647--C0014544                             0.0                   0.053292
# 135410875--CN077967                        0.0                   0.000000
#
#                      network--disease_signature  ...  go--disease_sequence  \
# 65028--C5203670                        0.000000  ...              0.000000
# 3005573--C0027661                      0.000000  ...              0.000000
# 3386--C0014544                         0.949993  ...              0.027795
# 3647--C0014544                         0.902558  ...              0.024480
# 135410875--CN077967                    0.000000  ...              0.000000
#
#                      go--disease_signature  go--disease_go  \
# 65028--C5203670                   0.000000        0.000000
# 3005573--C0027661                 0.000000        0.000000
# 3386--C0014544                    0.494638        0.184361
# 3647--C0014544                    0.527095        0.184693
# 135410875--CN077967               0.000000        0.000000
#
#                      go--disease_network  se--disease_phenotype  \
# 65028--C5203670                 0.000000               0.000000
# 3005573--C0027661               0.000000               0.543214
# 3386--C0014544                  0.470104               0.731552
# 3647--C0014544                  0.486478               0.790569
# 135410875--CN077967             0.000000               0.000000
#
#                      se--disease_semantic  se--disease_sequence  \
# 65028--C5203670                       0.0              0.000000
# 3005573--C0027661                     0.0              0.000000
# 3386--C0014544                        0.0              0.040366
# 3647--C0014544                        0.0              0.040307
# 135410875--CN077967                   0.0              0.000000
#
#                      se--disease_signature  se--disease_go  \
# 65028--C5203670                   0.000000        0.000000
# 3005573--C0027661                 0.000000        0.000000
# 3386--C0014544                    0.960719        0.344097
# 3647--C0014544                    0.964305        0.332425
# 135410875--CN077967               0.000000        0.000000
#
#                      se--disease_network
# 65028--C5203670                 0.000000
# 3005573--C0027661               0.000000
# 3386--C0014544                  0.937041
# 3647--C0014544                  0.931771
# 135410875--CN077967             0.000000
#
# [5 rows x 36 columns]

# %%
Associations.T
# Out:
#        65028--C5203670  3005573--C0027661  3386--C0014544  3647--C0014544  \
# Class             -1.0               -1.0            -1.0            -1.0
#
#        135410875--CN077967  135410875--C1387404  443879--C0042024  \
# Class                 -1.0                 -1.0              -1.0
#
#        443879--C0878773.1  6442177--C0278883  6442177--C0018133  ...  \
# Class                -1.0               -1.0               -1.0  ...
#
#        43672--C1263758  43672--C0033700  43672--C0003615  43672--C0242172  \
# Class              1.0              1.0              1.0              1.0
#
#        43672--C0014347  43672--C0153195  43672--C4273756  43672--C3163829  \
# Class              1.0              1.0              1.0              1.0
#
#        43672--C2020625  43672--C1318973
# Class              1.0              1.0
#
# [1 rows x 300 columns]

# %%
Features.to_csv("subset_features_PREDICT.csv")
Associations.to_csv("subset_associations_PREDICT.csv")

# %% [markdown]
# ## Larger PREDICT-like dataset

# %%
## Need to run the corresponding cells in PREDICT method.ipynb otherwise
if (os.path.exists(data_folder+"Features_PREDICT.csv")):
    Features = pd.read_csv(data_folder+"Features_PREDICT.csv", index_col=0).T
else:
    print("Run notebook PREDICT method.ipynb")
if (os.path.exists(data_folder+"Associations_PREDICT.csv")):
    A = pd.read_csv(data_folder+"Associations_PREDICT.csv", index_col=0)
    A.index = A.index.astype(str)
    A["Drug"] = list(A.index)
    Associations = A.melt(id_vars=["Drug"], var_name=["Disease"], value_name="Class", value_vars=A.columns[:-1])
    Associations.index = [s+"--"+p for s,p in Associations[["Drug","Disease"]].values.tolist()]
    Associations = Associations[["Class"]].loc[Features.index]
else:
    print("Run notebook PREDICT method.ipynb")
datasets_di.update({"PREDICT": {"Features": Features, "Associations": Associations}})
(Features.shape, Associations.shape)
# Out:
# ((20578, 36), (20578, 1))

# %% [markdown]
# ## Transcriptomic dataset

# %%
## Need to run the corresponding cells in custom_dataset.ipynb otherwise
if (os.path.exists(data_folder+"custom_dataset/A.csv")):
    A = pd.read_csv(data_folder+"custom_dataset/A.csv", index_col=0)
    A.index = A.index.astype(str)
else:
    print("Run notebook custom_dataset.ipynb")
if (os.path.exists(data_folder+"custom_dataset/P.csv") and os.path.exists(data_folder+"custom_dataset/S.csv")):
    P = pd.read_csv(data_folder+"custom_dataset/P.csv", index_col=0)
    S = pd.read_csv(data_folder+"custom_dataset/S.csv", index_col=0)
    S.columns = S.columns.astype(str)
    ## multiply expression values for a same gene in both drug and disease signature
    Known_1 = [[list(A.index)[i], list(A.columns)[j]] for i, j in np.argwhere(A.values==1).tolist()]
    Known_m1 = [[list(A.index)[i], list(A.columns)[j]] for i, j in np.argwhere(A.values==-1).tolist()]
    Nknown_1=700
    Nknown_m1=len(Known_m1)
    Npairs=20000

    from itertools import product
    ## pairs (drug,disease)
    pairs_names = []
    for e in product(*[list(S.columns),list(P.columns)]):
        if ((e[0] in A.index) and (e[1] in A.columns) and (A.loc[e[0]][e[1]]==0)):
            pairs_names.append(e)
        if (len(pairs_names)==Npairs):
            break

    pairs_names = Known_m1[:Nknown_m1]+pairs_names+Known_1[:Nknown_1]
    ## Here, features in S and in P are the same (genes)
    SS = S.loc[S.index][[p[0] for p in pairs_names]]
    PP = P.loc[S.index][[p[1] for p in pairs_names]]
    PP += (-1)**(PP.values<0) ##preserve the sign
    Features = np.multiply(SS,PP)
    Features.columns = ["--".join(p) for p in pairs_names]
    Features = Features.T
else:
    print("Run notebook custom_dataset.ipynb")
Features.head()
# Out:
#                        A1CF       A2M      AACS     AADAC  AADAT     AAMDC  \
# 145068--C0032285   0.000000  0.000000  0.000000  0.000000    0.0  0.000000
# 5284373--C0014544  0.006304 -0.002591 -0.000174 -0.002253    0.0 -0.005548
# 54687--C0014544   -0.003060 -0.004392  0.000316 -0.008325    0.0  0.006408
# 2284--C0014544    -0.005802 -0.003929  0.002782  0.016020    0.0  0.009123
# 2519--C0014544    -0.007447  0.007845  0.002025 -0.003146    0.0 -0.002169
#
#                        AAMP      AAR2  AARD      AARS  ...    ZSCAN9  ZSWIM6  \
# 145068--C0032285   0.000000  0.000000   0.0 -0.009582  ...  0.000000     0.0
# 5284373--C0014544 -0.017048 -0.006163   0.0  0.030322  ...  0.000814     0.0
# 54687--C0014544    0.001213 -0.001856   0.0  0.014672  ...  0.009547     0.0
# 2284--C0014544     0.008060 -0.004581   0.0 -0.006278  ... -0.003795     0.0
# 2519--C0014544     0.006753 -0.001677   0.0  0.005590  ... -0.004741     0.0
#
#                      ZSWIM8      ZW10     ZWINT      ZXDC  ZYG11B       ZYX  \
# 145068--C0032285   0.000000  0.000000  0.000000  0.000000     0.0  0.000000
# 5284373--C0014544  0.003978 -0.023151 -0.007352  0.012371     0.0 -0.025708
# 54687--C0014544    0.007889 -0.004885  0.001020  0.014016     0.0  0.011977
# 2284--C0014544     0.001538 -0.009056 -0.001609 -0.003781     0.0 -0.008824
# 2519--C0014544     0.002851 -0.009682  0.011514  0.008756     0.0  0.017358
#
#                       ZZEF1      ZZZ3
# 145068--C0032285   0.000000  0.000000
# 5284373--C0014544 -0.002286  0.012661
# 54687--C0014544   -0.011953 -0.003614
# 2284--C0014544    -0.006532  0.000967
# 2519--C0014544    -0.003349  0.002967
#
# [5 rows x 10811 columns]

# %%
if (os.path.exists(data_folder+"custom_dataset/A.csv")):
    A = pd.read_csv(data_folder+"custom_dataset/A.csv", index_col=0)
    A.index = A.index.astype(str)
    A["Drug"] = list(A.index)
    Associations = A.melt(id_vars=["Drug"], var_name=["Disease"], value_name="Class", value_vars=A.columns[:-1])
    Associations.index = [s+"--"+p for s,p in Associations[["Drug","Disease"]].values.tolist()]
    Associations = Associations[["Class"]].loc[Features.index]
else:
    print("Run notebook custom_dataset.ipynb")
Associations.T
# Out:
#        145068--C0032285  5284373--C0014544  54687--C0014544  2284--C0014544  \
# Class              -1.0               -1.0             -1.0            -1.0
#
#        2519--C0014544  5472--C0014544  2481--C0014544  4075--C0014544  \
# Class            -1.0            -1.0            -1.0            -1.0
#
#        2812--C0014544  2153--C0014544  ...  441203--C1140680  \
# Class            -1.0            -1.0  ...               1.0
#
#        441203--C0026764  2583--C0020538  4170--C0020538  176870--C0007131  \
# Class               1.0             1.0             1.0               1.0
#
#        6915944--C0275804  2764--C0010346  2764--C0004626  5388993--C0023467  \
# Class                1.0             1.0             1.0                1.0
#
#        5388993--C0027708
# Class                1.0
#
# [1 rows x 20348 columns]

# %%
datasets_di.update({"TRANSCRIPT": {"Features": Features, "Associations": Associations}})
(Features.shape, Associations.shape)
# Out:
# ((20348, 10811), (20348, 1))

# %% [markdown]
# ## Random (noninformative dataset)

# %%
import random
random.seed(0)
np.random.seed(0)

## notebook custom_dataset.ipynb
if (os.path.exists(data_folder+"featureless/all_ratings.csv")):
    A = pd.read_csv(data_folder+"featureless/all_ratings.csv", index_col=0)
    A.index = A.index.astype(str)
    A["Drug"] = list(A.index)
    Associations = A.melt(id_vars=["Drug"], var_name=["Disease"], value_name="Class", value_vars=A.columns[:-1])
    Associations.index = [s+"--"+p for s,p in Associations[["Drug","Disease"]].values.tolist()]
    Associations = Associations[["Class"]]
    
    Known_1 = [[list(A.index)[i], list(A.columns)[j]] for i, j in np.argwhere(A.values==1).tolist()]
    Known_m1 = [[list(A.index)[i], list(A.columns)[j]] for i, j in np.argwhere(A.values==-1).tolist()]
    Nknown_1=8000
    Nknown_m1=len(Known_m1)
    Npairs=20000

    from itertools import product
    ## pairs (drug,disease)
    pairs_names = []
    for e in product(*[list(A.index),list(A.columns)]):
        if ((e[0] in A.index) and (e[1] in A.columns) and (A.loc[e[0]][e[1]]==0)):
            pairs_names.append(e)
        if (len(pairs_names)==Npairs):
            break

    pairs_names = Known_m1[:Nknown_1]+pairs_names+Known_1[:Nknown_m1]
    nF = 100
    ## generate random features
    F = np.matrix(np.random.normal(0, 1, (len(pairs_names), nF)))
    Features = pd.DataFrame(F, index=["--".join(x) for x in pairs_names], columns=range(nF))
    
    Associations = Associations.loc[Features.index]
else:
    print("Run notebook custom_dataset.ipynb")
datasets_di.update({"Random": {"Features": Features, "Associations": Associations}})
(Features.shape, Associations.shape)
# Out:
# ((20640, 100), (20640, 1))

# %%
Associations.T
# Out:
#        DB00017--C0029408  5284373--C0014544  5284373--C0010034  \
# Class               -1.0               -1.0               -1.0
#
#        5284373--C0242770  448601--C0011884  54687--C0014544  2284--C0014544  \
# Class               -1.0              -1.0             -1.0            -1.0
#
#        387447--C1266036  2519--C0014544  5472--C0014544  ...  2771--C1856973  \
# Class              -1.0            -1.0            -1.0  ...             1.0
#
#        2771--C1850022  2771--C2675556  2771--C0028768  2771--C1868649  \
# Class             1.0             1.0             1.0             1.0
#
#        2771--C0001973  2771--C0011989  2771--C1866849  2771--C0270549  \
# Class             1.0             1.0             1.0             1.0
#
#        2771--C1269683
# Class             1.0
#
# [1 rows x 20640 columns]

# %%
Features.head()
# Out:
#                          0         1         2         3         4         5   \
# DB00017--C0029408  1.764052  0.400157  0.978738  2.240893  1.867558 -0.977278
# 5284373--C0014544  1.883151 -1.347759 -1.270485  0.969397 -1.173123  1.943621
# 5284373--C0010034 -0.369182 -0.239379  1.099660  0.655264  0.640132 -1.616956
# 5284373--C0242770 -1.306527  1.658131 -0.118164 -0.680178  0.666383 -0.460720
# 448601--C0011884  -0.598654 -1.115897  0.766663  0.356293 -1.768538  0.355482
#
#                          6         7         8         9   ...        90  \
# DB00017--C0029408  0.950088 -0.151357 -0.103219  0.410599  ... -0.403177
# 5284373--C0014544 -0.413619 -0.747455  1.922942  1.480515  ... -1.292857
# 5284373--C0010034 -0.024326 -0.738031  0.279925 -0.098150  ... -0.628088
# 5284373--C0242770 -1.334258 -1.346718  0.693773 -0.159573  ...  0.567290
# 448601--C0011884   0.814520  0.058926 -0.185054 -0.807648  ... -1.029935
#
#                          91        92        93        94        95        96  \
# DB00017--C0029408  1.222445  0.208275  0.976639  0.356366  0.706573  0.010500
# 5284373--C0014544  0.267051 -0.039283 -1.168093  0.523277 -0.171546  0.771791
# 5284373--C0010034 -0.481027  2.303917 -1.060016 -0.135950  1.136891  0.097725
# 5284373--C0242770 -0.222675 -0.353432 -1.616474 -0.291837 -0.761492  0.857924
# 448601--C0011884  -0.349943  1.100284  1.298022  2.696224 -0.073925 -0.658553
#
#                          97        98        99
# DB00017--C0029408  1.785870  0.126912  0.401989
# 5284373--C0014544  0.823504  2.163236  1.336528
# 5284373--C0010034  0.582954 -0.399449  0.370056
# 5284373--C0242770  1.141102  1.466579  0.852552
# 448601--C0011884  -0.514234 -1.018042 -0.077855
#
# [5 rows x 100 columns]

# %% [markdown]
# ## Benchmark datasets

# %% [raw]
# from utils import dataset_loading
# dataset_names = []#["Fdataset","DNdataset","Cdataset","Gottlieb"]
#
# for dataset_name in dataset_names:
#     print(dataset_name)
#     di = dataset_loading(dataset_name)
#     A, P, S = di["A"], di["P"], di["S"]
#     A.index = A.index.astype(str)
#     A.columns = A.columns.astype(str)
#     P.index = P.index.astype(str)
#     P.columns = P.columns.astype(str)
#     S.index = S.index.astype(str)
#     S.columns = S.columns.astype(str)
#
#     Known_1 = [[list(A.index)[i], list(A.columns)[j]] for i, j in np.argwhere(A.values==1).tolist()]
#     Known_m1 = [[list(A.index)[i], list(A.columns)[j]] for i, j in np.argwhere(A.values==-1).tolist()]
#     Nknown_1=1000
#     Nknown_m1=len(Known_m1)
#     Npairs=20000
#     from itertools import product
#     ## pairs (drug,disease)
#     pairs_names = []
#     for e in product(*[list(S.columns),list(P.columns)]):
#         if ((e[0] in A.index) and (e[1] in A.columns) and (A.loc[e[0]][e[1]]==0)):
#             pairs_names.append(e)
#         if (len(pairs_names)==Npairs):
#             break
#     pairs_names = Known_m1[:Nknown_1]+pairs_names+Known_1[:Nknown_m1]
#
#     Features = pd.DataFrame([],index=list(S.index)+list(P.index))
#     for p in pairs_names:
#         Features["--".join(p)] = list(S[p[0]])+list(P[p[1]])
#     Features = Features.T
#     print(Features.head())
#
#     A.index = A.index.astype(str)
#     A["Drug"] = list(A.index)
#     Associations = A.melt(id_vars=["Drug"], var_name=["Disease"], value_name="Class", value_vars=A.columns[:-1])
#     Associations.index = [s+"--"+p for s,p in Associations[["Drug","Disease"]].values.tolist()]
#     Associations = Associations[["Class"]].loc[Features.index]
#     print(Associations.T)
#
#     datasets_di.update({dataset_name, {"Features": Features, "Associations": Associations}})
#     print((Features.shape, Associations.shape))

# %% [markdown]
# ## Select one dataset

# %%
dataset_name = "Random"
Features, Associations = [datasets_di[dataset_name][v] for v in ["Features","Associations"]]

# %%
from copy import deepcopy
Feats = deepcopy(Features)
Feats.shape
# Out:
# (20640, 100)

# %%
## Remove pairs and features on which we have no information/that are not informative
Feats_nonzero = Feats.iloc[np.sum(Feats.values,axis=1)>0,np.sum(Feats.values,axis=0)>0]
Assocs = Associations.loc[Feats_nonzero.index]
Feats_nonzero.shape
# Out:
# (10520, 51)

# %%
## Remove multicollinearity
import matplotlib.pyplot as plt
cutoff=0.9

fig, ax = plt.subplots(nrows=1,ncols=2)
Corr = Feats_nonzero.corr(method="pearson")
ax[0].imshow(Corr)
ax[0].set_title("Before")
np.fill_diagonal(Corr.values, 0)
Feats_nocoll = Feats_nonzero[[c for c in Feats_nonzero.columns if (Corr.max(axis=1).loc[c]<cutoff)]]
Corr = Feats_nocoll.corr(method="pearson")
ax[1].imshow(Corr)
ax[1].set_title("After")
plt.show()
Feats_nocoll.shape
# Out:
# (10520, 51)

# %%
## "Remove multicollinearity" takes too much time for TRANSCRIPT, here is a shorter version
Ntop=100

VarGene = Feats_nonzero.var(axis=0).sort_values(ascending=False)
TopVarGene = list(VarGene.index)[:Ntop]
Feats_nocoll = Feats_nonzero[TopVarGene]
Corr = Feats_nocoll.corr(method="pearson")

import matplotlib.pyplot as plt
plt.imshow(Corr)
plt.title("After")
plt.show()
Feats_nocoll.shape
# Out:
# (9576, 100)

# %% [raw]
# ## Ensure linearity?
# from sklearn.linear_model import LinearRegression as LR
# cutoff=0.7
# def logtransform(AA, FF):
#     from copy import deepcopy
#     F = deepcopy(FF)
#     for f in F.columns:
#         X,y = F[[f]].values,np.ravel(AA.values)
#         Rsquared = LR().fit(X,y).score(X,y)
#         if (Rsquared<cutoff):
#             F[f] = np.log1p(FF[f])
#             X,y = F[[f]].values,np.ravel(AA.values)
#             Rsquared_n = LR().fit(X,y).score(X,y)
#             print((f,Rsquared,Rsquared_n))
#     return F
#
# Feats_logt = logtransform(Assocs,Feats_nocoll)
#
# fig, ax = plt.subplots(nrows=1,ncols=2)
# ax[0].imshow(Feats_nocoll.iloc[:10,:10])
# ax[0].set_title("Before")
# ax[1].imshow(Feats_logt.iloc[:10,:10])
# ax[1].set_title("After")
# plt.show()
# Feats_logt.shape

# %% [markdown]
# ## Preprocessing

# %%
from sklearn.preprocessing import StandardScaler

def output_features(YY, XX):
    ## Output vector & Features
    y = np.ravel(np.array(YY.fillna(0).values))
    y[y<0] = 0
    X = np.array(XX.fillna(0).values)
    X_scal = StandardScaler().fit_transform(X)
    return X_scal, y

# %% [markdown]
# ## Testing routine

# %%
## Prediction assessment: average of AUC scores for each iteration, each cross-validation

from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_validate
from sklearn.metrics import roc_curve
import random
random.seed(0)
Niter_CV=100 # number of times the cross-validation is run
Nfold_CV=5 # number of parts in cross-validation
Ntest_size=0.3 # test size proportion
Nhidden_size=0.1 # hidden drug proportion (for the validation set)

def testing_routine(MODEL, YY, XX, verbose=False, extreme_verbose=False):
    drug_list = list(set([idx.split("--")[0] for idx in XX.index]))
    seeds0 = [random.sample(range(int(1e8)),k=1)[0] for k in range(Niter_CV)]

    mean_auc_test, mean_auc_train = [None]*Niter_CV, [None]*Niter_CV
    mean_acc_test, mean_acc_train = [None]*Niter_CV, [None]*Niter_CV
    max_auc_test_di = {"fpr": None, "tpr": None}
    max_auc_test = -float("inf")

    for ns, seed0 in enumerate(seeds0):
        if (verbose):
            print("Iteration %d/%d" % (ns+1, len(seeds0)))
        random.seed(seed0)
        np.random.seed(seed0)
        hidden_drugs=random.sample(drug_list, k=int(Nhidden_size*len(drug_list))+1)
        if (extreme_verbose):
            print("%d/%d" % (len(hidden_drugs), len(drug_list)))
        cv = ShuffleSplit(n_splits=Nfold_CV, test_size=Ntest_size, random_state=seed0)

        ## Validation set
        XX_valid = XX.loc[[idx for idx in XX.index if (idx.split("--")[0] in hidden_drugs)]]
        YY_valid = YY.loc[[idx for idx in XX.index if (idx.split("--")[0] in hidden_drugs)]]

        if (extreme_verbose):
            print("Validation")
            print(XX_valid.shape)
            print(YY_valid.shape)

        ## Training/Testing sets
        XX_train_test = XX.loc[[idx for idx in XX.index if (idx.split("--")[0] not in hidden_drugs)]]
        YY_train_test = YY.loc[[idx for idx in XX.index if (idx.split("--")[0] not in hidden_drugs)]]

        if (extreme_verbose):
            print("Train/Test")
            print(XX_train_test.shape)
            print(YY_train_test.shape)

        ## Output vector & Features (Training/Testing)
        X_scal_train_test, y_train_test = output_features(YY_train_test, XX_train_test)

        ## Output vector & Features (Validation)
        X_scal_valid, y_valid = output_features(YY_valid, XX_valid)
        
        ## TODO: train/test should be split to avoid data leakage

        results_cv = cross_validate(MODEL(0), X_scal_train_test, y_train_test, cv=cv, return_train_score=True) #accuracy
        mean_acc_test[ns] = np.mean(results_cv['test_score'])
        mean_acc_train[ns] = np.mean(results_cv['train_score'])

        results_cv = cross_validate(MODEL(0), X_scal_train_test, y_train_test, cv=cv, scoring="roc_auc", return_train_score=True, return_estimator=True) #AUC
        mean_auc_test[ns] = np.mean(results_cv['test_score'])
        mean_auc_train[ns] = np.mean(results_cv['train_score'])

        max_auc_id = np.argmax(results_cv['test_score'])
        if (results_cv['test_score'][max_auc_id]>max_auc_test):
            max_estimator = results_cv['estimator'][max_auc_id]
            y_pred = max_estimator.predict(X_scal_valid)
            fpr, tpr, _ = roc_curve(y_valid, y_pred)

            max_auc_test_di.update({"fpr": fpr, "tpr": tpr})
            max_auc_test = results_cv['test_score'][max_auc_id]
        if (verbose):
            print("mean AUC on test set: %.2f\tmax AUC on test set so far: %.2f" % (mean_auc_test[ns],max_auc_test))

    print("mean AUC Train: %.2f (+- %.2f)\tTest: %.2f (+- %.2f)" % (np.mean(mean_auc_train), np.std(mean_auc_train),np.mean(mean_auc_test), np.std(mean_auc_test)))
    print("mean ACC Train: %.2f (+- %.2f)\tTest: %.2f (+- %.2f)" % (np.mean(mean_acc_train), np.std(mean_acc_train),np.mean(mean_acc_test), np.std(mean_acc_test)))
    return max_auc_test_di, max_auc_test

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

def ROC_curve(max_auc_test_di, max_auc_test):
    plt.figure()
    lw = 2
    plt.plot(
        max_auc_test_di["fpr"],
        max_auc_test_di["tpr"],
        color="darkorange",
        lw=lw,
        label="ROC curve (area = %0.2f)" % auc(max_auc_test_di["fpr"], max_auc_test_di["tpr"]),
    )
    plt.plot([0, 1], [0, 1], color="navy", lw=lw, linestyle="--")
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC of best model on validation (test AUC = %.2f)" % max_auc_test)
    plt.legend(loc="lower right")
    plt.show()

# %% [markdown]
# ## Methods

# %%
from sklearn.linear_model import LogisticRegression as Logit
params = {
    'max_iter':5000,
    'C':1.,
    'class_weight':"balanced",
    'penalty':"l2",
    'fit_intercept':True,
    'solver':"liblinear",
}
LOGIT_model = lambda x : Logit(**params, random_state=x)

# %%
from sklearn.naive_bayes import GaussianNB
BAYES_model = lambda x : GaussianNB()

# %%
from sklearn.svm import SVC
SVM_model = lambda x : SVC(C=1., kernel='rbf', random_state=x)

# %% [markdown]
# ## Methods (applied to PREDICT dataset)

# %%
AA = Assocs
FF = Feats_nocoll
(AA.shape,FF.shape)
# Out:
# ((12747, 1), (12747, 9))

# %%
a, b = testing_routine(LOGIT_model, AA, FF)
ROC_curve(a,b)
# Out:
# mean AUC Train: 0.77 (+- 0.02)	Test: 0.75 (+- 0.02)
# mean ACC Train: 0.77 (+- 0.02)	Test: 0.77 (+- 0.02)

# %%
a, b = testing_routine(BAYES_model, AA, FF)
ROC_curve(a,b)
# Out:
# mean AUC Train: 0.82 (+- 0.01)	Test: 0.81 (+- 0.02)
# mean ACC Train: 0.91 (+- 0.01)	Test: 0.91 (+- 0.01)

# %%
a, b = testing_routine(SVM_model, AA, FF, verbose=True)
ROC_curve(a,b)
# Out:
# Iteration 1/100
# mean AUC on test set: 0.87	max AUC on test set so far: 0.89
# Iteration 2/100
# mean AUC on test set: 0.82	max AUC on test set so far: 0.89
# Iteration 3/100
# mean AUC on test set: 0.81	max AUC on test set so far: 0.89
# Iteration 4/100
# mean AUC on test set: 0.78	max AUC on test set so far: 0.89
# Iteration 5/100
# mean AUC on test set: 0.82	max AUC on test set so far: 0.89
# Iteration 6/100
# mean AUC on test set: 0.82	max AUC on test set so far: 0.89
# Iteration 7/100
# mean AUC on test set: 0.80	max AUC on test set so far: 0.89
# Iteration 8/100
# mean AUC on test set: 0.76	max AUC on test set so far: 0.89
# Iteration 9/100
# mean AUC on test set: 0.75	max AUC on test set so far: 0.89
# Iteration 10/100
# mean AUC on test set: 0.80	max AUC on test set so far: 0.89
# Iteration 11/100
# mean AUC on test set: 0.81	max AUC on test set so far: 0.89
# Iteration 12/100
# mean AUC on test set: 0.80	max AUC on test set so far: 0.89
# Iteration 13/100
# mean AUC on test set: 0.76	max AUC on test set so far: 0.89
# Iteration 14/100
# mean AUC on test set: 0.76	max AUC on test set so far: 0.89
# Iteration 15/100
# mean AUC on test set: 0.81	max AUC on test set so far: 0.89
# Iteration 16/100
# mean AUC on test set: 0.79	max AUC on test set so far: 0.89
# Iteration 17/100
# mean AUC on test set: 0.77	max AUC on test set so far: 0.89
# Iteration 18/100
# mean AUC on test set: 0.79	max AUC on test set so far: 0.89
# Iteration 19/100
# mean AUC on test set: 0.79	max AUC on test set so far: 0.89
# Iteration 20/100
# mean AUC on test set: 0.77	max AUC on test set so far: 0.89
# Iteration 21/100
# mean AUC on test set: 0.79	max AUC on test set so far: 0.89
# Iteration 22/100
# mean AUC on test set: 0.79	max AUC on test set so far: 0.89
# Iteration 23/100
# mean AUC on test set: 0.80	max AUC on test set so far: 0.89
# Iteration 24/100
# mean AUC on test set: 0.83	max AUC on test set so far: 0.89
# Iteration 25/100
# mean AUC on test set: 0.82	max AUC on test set so far: 0.89
# Iteration 26/100
# mean AUC on test set: 0.80	max AUC on test set so far: 0.89
# Iteration 27/100
# mean AUC on test set: 0.79	max AUC on test set so far: 0.89
# Iteration 28/100
# mean AUC on test set: 0.83	max AUC on test set so far: 0.89
# Iteration 29/100
# mean AUC on test set: 0.84	max AUC on test set so far: 0.89
# Iteration 30/100
# mean AUC on test set: 0.83	max AUC on test set so far: 0.89
# Iteration 31/100
# mean AUC on test set: 0.79	max AUC on test set so far: 0.89
# Iteration 32/100
# mean AUC on test set: 0.77	max AUC on test set so far: 0.89
# Iteration 33/100
# mean AUC on test set: 0.79	max AUC on test set so far: 0.89
# Iteration 34/100
# mean AUC on test set: 0.82	max AUC on test set so far: 0.89
# Iteration 35/100
# mean AUC on test set: 0.79	max AUC on test set so far: 0.89
# Iteration 36/100
# mean AUC on test set: 0.81	max AUC on test set so far: 0.89
# Iteration 37/100
# mean AUC on test set: 0.80	max AUC on test set so far: 0.89
# Iteration 38/100
# mean AUC on test set: 0.77	max AUC on test set so far: 0.89
# Iteration 39/100
# mean AUC on test set: 0.76	max AUC on test set so far: 0.89
# Iteration 40/100
# mean AUC on test set: 0.79	max AUC on test set so far: 0.89
# Iteration 41/100
# mean AUC on test set: 0.80	max AUC on test set so far: 0.89
# Iteration 42/100
# mean AUC on test set: 0.73	max AUC on test set so far: 0.89
# Iteration 43/100
# mean AUC on test set: 0.83	max AUC on test set so far: 0.89
# Iteration 44/100
# mean AUC on test set: 0.80	max AUC on test set so far: 0.89
# Iteration 45/100
# mean AUC on test set: 0.86	max AUC on test set so far: 0.90
# Iteration 46/100
# mean AUC on test set: 0.82	max AUC on test set so far: 0.90
# Iteration 47/100
# mean AUC on test set: 0.85	max AUC on test set so far: 0.90
# Iteration 48/100
# mean AUC on test set: 0.79	max AUC on test set so far: 0.90
# Iteration 49/100
# mean AUC on test set: 0.79	max AUC on test set so far: 0.90
# Iteration 50/100
# mean AUC on test set: 0.80	max AUC on test set so far: 0.90
# Iteration 51/100
# mean AUC on test set: 0.79	max AUC on test set so far: 0.90
# Iteration 52/100
# mean AUC on test set: 0.80	max AUC on test set so far: 0.90
# Iteration 53/100
# mean AUC on test set: 0.80	max AUC on test set so far: 0.90
# Iteration 54/100
# mean AUC on test set: 0.79	max AUC on test set so far: 0.90
# Iteration 55/100
# mean AUC on test set: 0.77	max AUC on test set so far: 0.90
# Iteration 56/100
# mean AUC on test set: 0.83	max AUC on test set so far: 0.90
# Iteration 57/100
# mean AUC on test set: 0.86	max AUC on test set so far: 0.90
# Iteration 58/100
# mean AUC on test set: 0.82	max AUC on test set so far: 0.90
# Iteration 59/100
# mean AUC on test set: 0.80	max AUC on test set so far: 0.90
# Iteration 60/100
# mean AUC on test set: 0.77	max AUC on test set so far: 0.90
# Iteration 61/100
# mean AUC on test set: 0.81	max AUC on test set so far: 0.90
# Iteration 62/100
# mean AUC on test set: 0.87	max AUC on test set so far: 0.90
# Iteration 63/100
# mean AUC on test set: 0.77	max AUC on test set so far: 0.90
# Iteration 64/100
# mean AUC on test set: 0.78	max AUC on test set so far: 0.90
# Iteration 65/100
# mean AUC on test set: 0.85	max AUC on test set so far: 0.90
# Iteration 66/100
# mean AUC on test set: 0.74	max AUC on test set so far: 0.90
# Iteration 67/100
# mean AUC on test set: 0.81	max AUC on test set so far: 0.90
# Iteration 68/100
# mean AUC on test set: 0.83	max AUC on test set so far: 0.90
# Iteration 69/100
# mean AUC on test set: 0.86	max AUC on test set so far: 0.90
# Iteration 70/100
# mean AUC on test set: 0.79	max AUC on test set so far: 0.90
# Iteration 71/100
# mean AUC on test set: 0.73	max AUC on test set so far: 0.90
# Iteration 72/100
# mean AUC on test set: 0.83	max AUC on test set so far: 0.90
# Iteration 73/100
# mean AUC on test set: 0.80	max AUC on test set so far: 0.90
# Iteration 74/100
# mean AUC on test set: 0.76	max AUC on test set so far: 0.90
# Iteration 75/100
# mean AUC on test set: 0.82	max AUC on test set so far: 0.90
# Iteration 76/100
# mean AUC on test set: 0.77	max AUC on test set so far: 0.90
# Iteration 77/100
# mean AUC on test set: 0.81	max AUC on test set so far: 0.90
# Iteration 78/100
# mean AUC on test set: 0.77	max AUC on test set so far: 0.90
# Iteration 79/100
# mean AUC on test set: 0.79	max AUC on test set so far: 0.90
# Iteration 80/100
# mean AUC on test set: 0.75	max AUC on test set so far: 0.90
# Iteration 81/100
# mean AUC on test set: 0.80	max AUC on test set so far: 0.90
# Iteration 82/100
# mean AUC on test set: 0.78	max AUC on test set so far: 0.90
# Iteration 83/100
# mean AUC on test set: 0.77	max AUC on test set so far: 0.90
# Iteration 84/100
# mean AUC on test set: 0.78	max AUC on test set so far: 0.90
# Iteration 85/100
# mean AUC on test set: 0.76	max AUC on test set so far: 0.90
# Iteration 86/100
# mean AUC on test set: 0.78	max AUC on test set so far: 0.90
# Iteration 87/100
# mean AUC on test set: 0.82	max AUC on test set so far: 0.90
# Iteration 88/100
# mean AUC on test set: 0.78	max AUC on test set so far: 0.90
# Iteration 89/100
# mean AUC on test set: 0.79	max AUC on test set so far: 0.90
# Iteration 90/100
# mean AUC on test set: 0.79	max AUC on test set so far: 0.90
# Iteration 91/100
# mean AUC on test set: 0.79	max AUC on test set so far: 0.90
# Iteration 92/100
# mean AUC on test set: 0.82	max AUC on test set so far: 0.90
# Iteration 93/100
# mean AUC on test set: 0.81	max AUC on test set so far: 0.90
# Iteration 94/100
# mean AUC on test set: 0.83	max AUC on test set so far: 0.90
# Iteration 95/100
# mean AUC on test set: 0.78	max AUC on test set so far: 0.90
# Iteration 96/100
# mean AUC on test set: 0.80	max AUC on test set so far: 0.90
# Iteration 97/100
# mean AUC on test set: 0.81	max AUC on test set so far: 0.90
# Iteration 98/100
# mean AUC on test set: 0.80	max AUC on test set so far: 0.90
# Iteration 99/100
# mean AUC on test set: 0.82	max AUC on test set so far: 0.90
# Iteration 100/100
# mean AUC on test set: 0.81	max AUC on test set so far: 0.90
# mean AUC Train: 0.87 (+- 0.02)	Test: 0.80 (+- 0.03)
# mean ACC Train: 0.99 (+- 0.00)	Test: 0.99 (+- 0.00)

# %% [markdown]
# ## Methods (applied to TRANSCRIPT dataset)

# %%
AA = Assocs
FF = Feats_nocoll
(AA.shape,FF.shape)
# Out:
# ((9576, 1), (9576, 100))

# %%
a, b = testing_routine(LOGIT_model, AA, FF, verbose=True)
ROC_curve(a,b)
# Out:
# Iteration 1/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.66
# Iteration 2/100
# mean AUC on test set: 0.63	max AUC on test set so far: 0.67
# Iteration 3/100
# mean AUC on test set: 0.59	max AUC on test set so far: 0.67
# Iteration 4/100
# mean AUC on test set: 0.67	max AUC on test set so far: 0.69
# Iteration 5/100
# mean AUC on test set: 0.66	max AUC on test set so far: 0.72
# Iteration 6/100
# mean AUC on test set: 0.66	max AUC on test set so far: 0.76
# Iteration 7/100
# mean AUC on test set: 0.62	max AUC on test set so far: 0.76
# Iteration 8/100
# mean AUC on test set: 0.66	max AUC on test set so far: 0.76
# Iteration 9/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.76
# Iteration 10/100
# mean AUC on test set: 0.62	max AUC on test set so far: 0.76
# Iteration 11/100
# mean AUC on test set: 0.62	max AUC on test set so far: 0.76
# Iteration 12/100
# mean AUC on test set: 0.65	max AUC on test set so far: 0.76
# Iteration 13/100
# mean AUC on test set: 0.66	max AUC on test set so far: 0.76
# Iteration 14/100
# mean AUC on test set: 0.62	max AUC on test set so far: 0.76
# Iteration 15/100
# mean AUC on test set: 0.62	max AUC on test set so far: 0.76
# Iteration 16/100
# mean AUC on test set: 0.63	max AUC on test set so far: 0.76
# Iteration 17/100
# mean AUC on test set: 0.62	max AUC on test set so far: 0.76
# Iteration 18/100
# mean AUC on test set: 0.65	max AUC on test set so far: 0.76
# Iteration 19/100
# mean AUC on test set: 0.65	max AUC on test set so far: 0.76
# Iteration 20/100
# mean AUC on test set: 0.59	max AUC on test set so far: 0.76
# Iteration 21/100
# mean AUC on test set: 0.57	max AUC on test set so far: 0.76
# Iteration 22/100
# mean AUC on test set: 0.58	max AUC on test set so far: 0.76
# Iteration 23/100
# mean AUC on test set: 0.64	max AUC on test set so far: 0.76
# Iteration 24/100
# mean AUC on test set: 0.66	max AUC on test set so far: 0.76
# Iteration 25/100
# mean AUC on test set: 0.64	max AUC on test set so far: 0.76
# Iteration 26/100
# mean AUC on test set: 0.62	max AUC on test set so far: 0.76
# Iteration 27/100
# mean AUC on test set: 0.64	max AUC on test set so far: 0.76
# Iteration 28/100
# mean AUC on test set: 0.63	max AUC on test set so far: 0.76
# Iteration 29/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.76
# Iteration 30/100
# mean AUC on test set: 0.69	max AUC on test set so far: 0.76
# Iteration 31/100
# mean AUC on test set: 0.67	max AUC on test set so far: 0.76
# Iteration 32/100
# mean AUC on test set: 0.66	max AUC on test set so far: 0.76
# Iteration 33/100
# mean AUC on test set: 0.64	max AUC on test set so far: 0.76
# Iteration 34/100
# mean AUC on test set: 0.65	max AUC on test set so far: 0.76
# Iteration 35/100
# mean AUC on test set: 0.62	max AUC on test set so far: 0.76
# Iteration 36/100
# mean AUC on test set: 0.62	max AUC on test set so far: 0.76
# Iteration 37/100
# mean AUC on test set: 0.59	max AUC on test set so far: 0.76
# Iteration 38/100
# mean AUC on test set: 0.69	max AUC on test set so far: 0.76
# Iteration 39/100
# mean AUC on test set: 0.64	max AUC on test set so far: 0.76
# Iteration 40/100
# mean AUC on test set: 0.63	max AUC on test set so far: 0.76
# Iteration 41/100
# mean AUC on test set: 0.62	max AUC on test set so far: 0.76
# Iteration 42/100
# mean AUC on test set: 0.66	max AUC on test set so far: 0.76
# Iteration 43/100
# mean AUC on test set: 0.57	max AUC on test set so far: 0.76
# Iteration 44/100
# mean AUC on test set: 0.66	max AUC on test set so far: 0.76
# Iteration 45/100
# mean AUC on test set: 0.65	max AUC on test set so far: 0.76
# Iteration 46/100
# mean AUC on test set: 0.66	max AUC on test set so far: 0.76
# Iteration 47/100
# mean AUC on test set: 0.62	max AUC on test set so far: 0.76
# Iteration 48/100
# mean AUC on test set: 0.62	max AUC on test set so far: 0.76
# Iteration 49/100
# mean AUC on test set: 0.69	max AUC on test set so far: 0.78
# Iteration 50/100
# mean AUC on test set: 0.64	max AUC on test set so far: 0.78
# Iteration 51/100
# mean AUC on test set: 0.65	max AUC on test set so far: 0.78
# Iteration 52/100
# mean AUC on test set: 0.67	max AUC on test set so far: 0.78
# Iteration 53/100
# mean AUC on test set: 0.63	max AUC on test set so far: 0.78
# Iteration 54/100
# mean AUC on test set: 0.71	max AUC on test set so far: 0.78
# Iteration 55/100
# mean AUC on test set: 0.67	max AUC on test set so far: 0.78
# Iteration 56/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.78
# Iteration 57/100
# mean AUC on test set: 0.62	max AUC on test set so far: 0.78
# Iteration 58/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.78
# Iteration 59/100
# mean AUC on test set: 0.63	max AUC on test set so far: 0.78
# Iteration 60/100
# mean AUC on test set: 0.68	max AUC on test set so far: 0.78
# Iteration 61/100
# mean AUC on test set: 0.63	max AUC on test set so far: 0.78
# Iteration 62/100
# mean AUC on test set: 0.64	max AUC on test set so far: 0.78
# Iteration 63/100
# mean AUC on test set: 0.63	max AUC on test set so far: 0.78
# Iteration 64/100
# mean AUC on test set: 0.62	max AUC on test set so far: 0.78
# Iteration 65/100
# mean AUC on test set: 0.54	max AUC on test set so far: 0.78
# Iteration 66/100
# mean AUC on test set: 0.63	max AUC on test set so far: 0.78
# Iteration 67/100
# mean AUC on test set: 0.67	max AUC on test set so far: 0.78
# Iteration 68/100
# mean AUC on test set: 0.64	max AUC on test set so far: 0.78
# Iteration 69/100
# mean AUC on test set: 0.65	max AUC on test set so far: 0.78
# Iteration 70/100
# mean AUC on test set: 0.66	max AUC on test set so far: 0.78
# Iteration 71/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.78
# Iteration 72/100
# mean AUC on test set: 0.63	max AUC on test set so far: 0.78
# Iteration 73/100
# mean AUC on test set: 0.71	max AUC on test set so far: 0.78
# Iteration 74/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.78
# Iteration 75/100
# mean AUC on test set: 0.67	max AUC on test set so far: 0.78
# Iteration 76/100
# mean AUC on test set: 0.67	max AUC on test set so far: 0.78
# Iteration 77/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.78
# Iteration 78/100
# mean AUC on test set: 0.63	max AUC on test set so far: 0.78
# Iteration 79/100
# mean AUC on test set: 0.65	max AUC on test set so far: 0.78
# Iteration 80/100
# mean AUC on test set: 0.58	max AUC on test set so far: 0.78
# Iteration 81/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.78
# Iteration 82/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.78
# Iteration 83/100
# mean AUC on test set: 0.69	max AUC on test set so far: 0.78
# Iteration 84/100
# mean AUC on test set: 0.64	max AUC on test set so far: 0.78
# Iteration 85/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.78
# Iteration 86/100
# mean AUC on test set: 0.64	max AUC on test set so far: 0.78
# Iteration 87/100
# mean AUC on test set: 0.62	max AUC on test set so far: 0.78
# Iteration 88/100
# mean AUC on test set: 0.63	max AUC on test set so far: 0.78
# Iteration 89/100
# mean AUC on test set: 0.66	max AUC on test set so far: 0.78
# Iteration 90/100
# mean AUC on test set: 0.64	max AUC on test set so far: 0.78
# Iteration 91/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.78
# Iteration 92/100
# mean AUC on test set: 0.64	max AUC on test set so far: 0.78
# Iteration 93/100
# mean AUC on test set: 0.63	max AUC on test set so far: 0.78
# Iteration 94/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.78
# Iteration 95/100
# mean AUC on test set: 0.70	max AUC on test set so far: 0.78
# Iteration 96/100
# mean AUC on test set: 0.63	max AUC on test set so far: 0.78
# Iteration 97/100
# mean AUC on test set: 0.65	max AUC on test set so far: 0.78
# Iteration 98/100
# mean AUC on test set: 0.62	max AUC on test set so far: 0.78
# Iteration 99/100
# mean AUC on test set: 0.64	max AUC on test set so far: 0.78
# Iteration 100/100
# mean AUC on test set: 0.70	max AUC on test set so far: 0.82
# mean AUC Train: 0.90 (+- 0.01)	Test: 0.64 (+- 0.03)
# mean ACC Train: 0.79 (+- 0.02)	Test: 0.78 (+- 0.02)

# %%
a, b = testing_routine(BAYES_model, AA, FF, verbose=True)
ROC_curve(a,b)
# Out:
# Iteration 1/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.62
# Iteration 2/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.62
# Iteration 3/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.62
# Iteration 4/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.63
# Iteration 5/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.63
# Iteration 6/100
# mean AUC on test set: 0.59	max AUC on test set so far: 0.63
# Iteration 7/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.63
# Iteration 8/100
# mean AUC on test set: 0.59	max AUC on test set so far: 0.63
# Iteration 9/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.63
# Iteration 10/100
# mean AUC on test set: 0.62	max AUC on test set so far: 0.63
# Iteration 11/100
# mean AUC on test set: 0.59	max AUC on test set so far: 0.63
# Iteration 12/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.63
# Iteration 13/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.63
# Iteration 14/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.63
# Iteration 15/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.63
# Iteration 16/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.63
# Iteration 17/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.63
# Iteration 18/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.63
# Iteration 19/100
# mean AUC on test set: 0.59	max AUC on test set so far: 0.63
# Iteration 20/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.63
# Iteration 21/100
# mean AUC on test set: 0.59	max AUC on test set so far: 0.63
# Iteration 22/100
# mean AUC on test set: 0.62	max AUC on test set so far: 0.63
# Iteration 23/100
# mean AUC on test set: 0.59	max AUC on test set so far: 0.63
# Iteration 24/100
# mean AUC on test set: 0.59	max AUC on test set so far: 0.63
# Iteration 25/100
# mean AUC on test set: 0.62	max AUC on test set so far: 0.63
# Iteration 26/100
# mean AUC on test set: 0.59	max AUC on test set so far: 0.63
# Iteration 27/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.63
# Iteration 28/100
# mean AUC on test set: 0.59	max AUC on test set so far: 0.63
# Iteration 29/100
# mean AUC on test set: 0.59	max AUC on test set so far: 0.63
# Iteration 30/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.63
# Iteration 31/100
# mean AUC on test set: 0.59	max AUC on test set so far: 0.63
# Iteration 32/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.63
# Iteration 33/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.63
# Iteration 34/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.63
# Iteration 35/100
# mean AUC on test set: 0.59	max AUC on test set so far: 0.63
# Iteration 36/100
# mean AUC on test set: 0.62	max AUC on test set so far: 0.63
# Iteration 37/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.63
# Iteration 38/100
# mean AUC on test set: 0.57	max AUC on test set so far: 0.63
# Iteration 39/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.63
# Iteration 40/100
# mean AUC on test set: 0.59	max AUC on test set so far: 0.63
# Iteration 41/100
# mean AUC on test set: 0.58	max AUC on test set so far: 0.63
# Iteration 42/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.63
# Iteration 43/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.63
# Iteration 44/100
# mean AUC on test set: 0.58	max AUC on test set so far: 0.63
# Iteration 45/100
# mean AUC on test set: 0.62	max AUC on test set so far: 0.63
# Iteration 46/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.63
# Iteration 47/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.63
# Iteration 48/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.63
# Iteration 49/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.63
# Iteration 50/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.63
# Iteration 51/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.63
# Iteration 52/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.63
# Iteration 53/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.63
# Iteration 54/100
# mean AUC on test set: 0.62	max AUC on test set so far: 0.64
# Iteration 55/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.64
# Iteration 56/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.64
# Iteration 57/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.64
# Iteration 58/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.64
# Iteration 59/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.64
# Iteration 60/100
# mean AUC on test set: 0.59	max AUC on test set so far: 0.64
# Iteration 61/100
# mean AUC on test set: 0.58	max AUC on test set so far: 0.64
# Iteration 62/100
# mean AUC on test set: 0.59	max AUC on test set so far: 0.64
# Iteration 63/100
# mean AUC on test set: 0.59	max AUC on test set so far: 0.64
# Iteration 64/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.64
# Iteration 65/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.64
# Iteration 66/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.64
# Iteration 67/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.64
# Iteration 68/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.64
# Iteration 69/100
# mean AUC on test set: 0.58	max AUC on test set so far: 0.64
# Iteration 70/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.64
# Iteration 71/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.64
# Iteration 72/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.64
# Iteration 73/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.64
# Iteration 74/100
# mean AUC on test set: 0.62	max AUC on test set so far: 0.64
# Iteration 75/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.64
# Iteration 76/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.64
# Iteration 77/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.64
# Iteration 78/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.64
# Iteration 79/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.64
# Iteration 80/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.64
# Iteration 81/100
# mean AUC on test set: 0.62	max AUC on test set so far: 0.64
# Iteration 82/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.64
# Iteration 83/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.64
# Iteration 84/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.64
# Iteration 85/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.64
# Iteration 86/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.64
# Iteration 87/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.64
# Iteration 88/100
# mean AUC on test set: 0.59	max AUC on test set so far: 0.64
# Iteration 89/100
# mean AUC on test set: 0.62	max AUC on test set so far: 0.64
# Iteration 90/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.64
# Iteration 91/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.64
# Iteration 92/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.64
# Iteration 93/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.64
# Iteration 94/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.64
# Iteration 95/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.64
# Iteration 96/100
# mean AUC on test set: 0.59	max AUC on test set so far: 0.64
# Iteration 97/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.64
# Iteration 98/100
# mean AUC on test set: 0.58	max AUC on test set so far: 0.64
# Iteration 99/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.64
# Iteration 100/100
# mean AUC on test set: 0.59	max AUC on test set so far: 0.64
# mean AUC Train: 0.61 (+- 0.01)	Test: 0.60 (+- 0.01)
# mean ACC Train: 0.22 (+- 0.02)	Test: 0.22 (+- 0.02)

# %%
a, b = testing_routine(SVM_model, AA, FF, verbose=True)
ROC_curve(a,b)
# Out:
# Iteration 1/100
# mean AUC on test set: 0.69	max AUC on test set so far: 0.75
# Iteration 2/100
# mean AUC on test set: 0.65	max AUC on test set so far: 0.75
# Iteration 3/100
# mean AUC on test set: 0.65	max AUC on test set so far: 0.75
# Iteration 4/100
# mean AUC on test set: 0.63	max AUC on test set so far: 0.75
# Iteration 5/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.75
# Iteration 6/100
# mean AUC on test set: 0.63	max AUC on test set so far: 0.75
# Iteration 7/100
# mean AUC on test set: 0.74	max AUC on test set so far: 0.82
# Iteration 8/100
# mean AUC on test set: 0.69	max AUC on test set so far: 0.82
# Iteration 9/100
# mean AUC on test set: 0.66	max AUC on test set so far: 0.82
# Iteration 10/100
# mean AUC on test set: 0.68	max AUC on test set so far: 0.82
# Iteration 11/100
# mean AUC on test set: 0.73	max AUC on test set so far: 0.82
# Iteration 12/100
# mean AUC on test set: 0.67	max AUC on test set so far: 0.82
# Iteration 13/100
# mean AUC on test set: 0.63	max AUC on test set so far: 0.82
# Iteration 14/100
# mean AUC on test set: 0.64	max AUC on test set so far: 0.82
# Iteration 15/100
# mean AUC on test set: 0.66	max AUC on test set so far: 0.82
# Iteration 16/100
# mean AUC on test set: 0.56	max AUC on test set so far: 0.82
# Iteration 17/100
# mean AUC on test set: 0.70	max AUC on test set so far: 0.82
# Iteration 18/100
# mean AUC on test set: 0.57	max AUC on test set so far: 0.82
# Iteration 19/100
# mean AUC on test set: 0.69	max AUC on test set so far: 0.82
# Iteration 20/100
# mean AUC on test set: 0.69	max AUC on test set so far: 0.82
# Iteration 21/100
# mean AUC on test set: 0.66	max AUC on test set so far: 0.82
# Iteration 22/100
# mean AUC on test set: 0.66	max AUC on test set so far: 0.82
# Iteration 23/100
# mean AUC on test set: 0.54	max AUC on test set so far: 0.82
# Iteration 24/100
# mean AUC on test set: 0.71	max AUC on test set so far: 0.82
# Iteration 25/100
# mean AUC on test set: 0.67	max AUC on test set so far: 0.82
# Iteration 26/100
# mean AUC on test set: 0.64	max AUC on test set so far: 0.82
# Iteration 27/100
# mean AUC on test set: 0.69	max AUC on test set so far: 0.82
# Iteration 28/100
# mean AUC on test set: 0.70	max AUC on test set so far: 0.82
# Iteration 29/100
# mean AUC on test set: 0.71	max AUC on test set so far: 0.82
# Iteration 30/100
# mean AUC on test set: 0.66	max AUC on test set so far: 0.82
# Iteration 31/100
# mean AUC on test set: 0.65	max AUC on test set so far: 0.82
# Iteration 32/100
# mean AUC on test set: 0.67	max AUC on test set so far: 0.82
# Iteration 33/100
# mean AUC on test set: 0.66	max AUC on test set so far: 0.82
# Iteration 34/100
# mean AUC on test set: 0.70	max AUC on test set so far: 0.82
# Iteration 35/100
# mean AUC on test set: 0.69	max AUC on test set so far: 0.82
# Iteration 36/100
# mean AUC on test set: 0.67	max AUC on test set so far: 0.82
# Iteration 37/100
# mean AUC on test set: 0.70	max AUC on test set so far: 0.82
# Iteration 38/100
# mean AUC on test set: 0.65	max AUC on test set so far: 0.82
# Iteration 39/100
# mean AUC on test set: 0.69	max AUC on test set so far: 0.82
# Iteration 40/100
# mean AUC on test set: 0.65	max AUC on test set so far: 0.82
# Iteration 41/100
# mean AUC on test set: 0.63	max AUC on test set so far: 0.82
# Iteration 42/100
# mean AUC on test set: 0.66	max AUC on test set so far: 0.82
# Iteration 43/100
# mean AUC on test set: 0.67	max AUC on test set so far: 0.82
# Iteration 44/100
# mean AUC on test set: 0.61	max AUC on test set so far: 0.82
# Iteration 45/100
# mean AUC on test set: 0.64	max AUC on test set so far: 0.82
# Iteration 46/100
# mean AUC on test set: 0.66	max AUC on test set so far: 0.82
# Iteration 47/100
# mean AUC on test set: 0.72	max AUC on test set so far: 0.82
# Iteration 48/100
# mean AUC on test set: 0.67	max AUC on test set so far: 0.82
# Iteration 49/100
# mean AUC on test set: 0.69	max AUC on test set so far: 0.82
# Iteration 50/100
# mean AUC on test set: 0.71	max AUC on test set so far: 0.82
# Iteration 51/100
# mean AUC on test set: 0.70	max AUC on test set so far: 0.82
# Iteration 52/100
# mean AUC on test set: 0.69	max AUC on test set so far: 0.82
# Iteration 53/100
# mean AUC on test set: 0.68	max AUC on test set so far: 0.82
# Iteration 54/100
# mean AUC on test set: 0.65	max AUC on test set so far: 0.82
# Iteration 55/100
# mean AUC on test set: 0.68	max AUC on test set so far: 0.82
# Iteration 56/100
# mean AUC on test set: 0.64	max AUC on test set so far: 0.82
# Iteration 57/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.82
# Iteration 58/100
# mean AUC on test set: 0.68	max AUC on test set so far: 0.82
# Iteration 59/100
# mean AUC on test set: 0.71	max AUC on test set so far: 0.82
# Iteration 60/100
# mean AUC on test set: 0.67	max AUC on test set so far: 0.82
# Iteration 61/100
# mean AUC on test set: 0.66	max AUC on test set so far: 0.82
# Iteration 62/100
# mean AUC on test set: 0.67	max AUC on test set so far: 0.82
# Iteration 63/100
# mean AUC on test set: 0.75	max AUC on test set so far: 0.82
# Iteration 64/100
# mean AUC on test set: 0.71	max AUC on test set so far: 0.82
# Iteration 65/100
# mean AUC on test set: 0.65	max AUC on test set so far: 0.82
# Iteration 66/100
# mean AUC on test set: 0.72	max AUC on test set so far: 0.82
# Iteration 67/100
# mean AUC on test set: 0.66	max AUC on test set so far: 0.82
# Iteration 68/100
# mean AUC on test set: 0.69	max AUC on test set so far: 0.82
# Iteration 69/100
# mean AUC on test set: 0.69	max AUC on test set so far: 0.82
# Iteration 70/100
# mean AUC on test set: 0.67	max AUC on test set so far: 0.82
# Iteration 71/100
# mean AUC on test set: 0.73	max AUC on test set so far: 0.82
# Iteration 72/100
# mean AUC on test set: 0.63	max AUC on test set so far: 0.82
# Iteration 73/100
# mean AUC on test set: 0.54	max AUC on test set so far: 0.82
# Iteration 74/100
# mean AUC on test set: 0.70	max AUC on test set so far: 0.82
# Iteration 75/100
# mean AUC on test set: 0.65	max AUC on test set so far: 0.82
# Iteration 76/100
# mean AUC on test set: 0.68	max AUC on test set so far: 0.82
# Iteration 77/100
# mean AUC on test set: 0.62	max AUC on test set so far: 0.82
# Iteration 78/100
# mean AUC on test set: 0.66	max AUC on test set so far: 0.82
# Iteration 79/100
# mean AUC on test set: 0.67	max AUC on test set so far: 0.82
# Iteration 80/100
# mean AUC on test set: 0.56	max AUC on test set so far: 0.82
# Iteration 81/100
# mean AUC on test set: 0.64	max AUC on test set so far: 0.82
# Iteration 82/100
# mean AUC on test set: 0.59	max AUC on test set so far: 0.82
# Iteration 83/100
# mean AUC on test set: 0.64	max AUC on test set so far: 0.82
# Iteration 84/100
# mean AUC on test set: 0.57	max AUC on test set so far: 0.82
# Iteration 85/100
# mean AUC on test set: 0.62	max AUC on test set so far: 0.82
# Iteration 86/100
# mean AUC on test set: 0.65	max AUC on test set so far: 0.82
# Iteration 87/100
# mean AUC on test set: 0.67	max AUC on test set so far: 0.82
# Iteration 88/100
# mean AUC on test set: 0.67	max AUC on test set so far: 0.82
# Iteration 89/100
# mean AUC on test set: 0.68	max AUC on test set so far: 0.82
# Iteration 90/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.82
# Iteration 91/100
# mean AUC on test set: 0.70	max AUC on test set so far: 0.82
# Iteration 92/100
# mean AUC on test set: 0.69	max AUC on test set so far: 0.82
# Iteration 93/100
# mean AUC on test set: 0.56	max AUC on test set so far: 0.82
# Iteration 94/100
# mean AUC on test set: 0.66	max AUC on test set so far: 0.82
# Iteration 95/100
# mean AUC on test set: 0.60	max AUC on test set so far: 0.82
# Iteration 96/100
# mean AUC on test set: 0.71	max AUC on test set so far: 0.82
# Iteration 97/100
# mean AUC on test set: 0.70	max AUC on test set so far: 0.82
# Iteration 98/100
# mean AUC on test set: 0.74	max AUC on test set so far: 0.91
# Iteration 99/100
# mean AUC on test set: 0.64	max AUC on test set so far: 0.91
# Iteration 100/100
# mean AUC on test set: 0.72	max AUC on test set so far: 0.91
# mean AUC Train: 0.99 (+- 0.00)	Test: 0.66 (+- 0.04)
# mean ACC Train: 0.99 (+- 0.00)	Test: 0.99 (+- 0.00)

# %% [markdown]
# ## Methods (applied to Random dataset)

# %%
AA = Assocs
FF = Feats_nocoll
(AA.shape,FF.shape)
# Out:
# ((10520, 1), (10520, 51))

# %%
a, b = testing_routine(LOGIT_model, AA, FF, verbose=True)
ROC_curve(a,b)
# Out:
# Iteration 1/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.56
# Iteration 2/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.56
# Iteration 3/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.56
# Iteration 4/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.56
# Iteration 5/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.56
# Iteration 6/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.58
# Iteration 7/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.58
# Iteration 8/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.58
# Iteration 9/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.58
# Iteration 10/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.58
# Iteration 11/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.58
# Iteration 12/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.58
# Iteration 13/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.58
# Iteration 14/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.58
# Iteration 15/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.58
# Iteration 16/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.58
# Iteration 17/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.58
# Iteration 18/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.58
# Iteration 19/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.58
# Iteration 20/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.58
# Iteration 21/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.58
# Iteration 22/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.58
# Iteration 23/100
# mean AUC on test set: 0.46	max AUC on test set so far: 0.58
# Iteration 24/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.58
# Iteration 25/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.58
# Iteration 26/100
# mean AUC on test set: 0.47	max AUC on test set so far: 0.58
# Iteration 27/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.58
# Iteration 28/100
# mean AUC on test set: 0.53	max AUC on test set so far: 0.58
# Iteration 29/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.58
# Iteration 30/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.58
# Iteration 31/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.58
# Iteration 32/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.58
# Iteration 33/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.58
# Iteration 34/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.58
# Iteration 35/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.58
# Iteration 36/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.58
# Iteration 37/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.58
# Iteration 38/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.58
# Iteration 39/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.58
# Iteration 40/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.58
# Iteration 41/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.58
# Iteration 42/100
# mean AUC on test set: 0.47	max AUC on test set so far: 0.58
# Iteration 43/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.58
# Iteration 44/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.58
# Iteration 45/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.58
# Iteration 46/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.58
# Iteration 47/100
# mean AUC on test set: 0.47	max AUC on test set so far: 0.58
# Iteration 48/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.58
# Iteration 49/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.58
# Iteration 50/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.58
# Iteration 51/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.59
# Iteration 52/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.59
# Iteration 53/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.59
# Iteration 54/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.59
# Iteration 55/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.59
# Iteration 56/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.59
# Iteration 57/100
# mean AUC on test set: 0.47	max AUC on test set so far: 0.59
# Iteration 58/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.59
# Iteration 59/100
# mean AUC on test set: 0.47	max AUC on test set so far: 0.59
# Iteration 60/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.59
# Iteration 61/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.59
# Iteration 62/100
# mean AUC on test set: 0.53	max AUC on test set so far: 0.59
# Iteration 63/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.59
# Iteration 64/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.59
# Iteration 65/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.59
# Iteration 66/100
# mean AUC on test set: 0.47	max AUC on test set so far: 0.59
# Iteration 67/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.59
# Iteration 68/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.59
# Iteration 69/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.59
# Iteration 70/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.59
# Iteration 71/100
# mean AUC on test set: 0.54	max AUC on test set so far: 0.59
# Iteration 72/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.59
# Iteration 73/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.59
# Iteration 74/100
# mean AUC on test set: 0.54	max AUC on test set so far: 0.59
# Iteration 75/100
# mean AUC on test set: 0.45	max AUC on test set so far: 0.59
# Iteration 76/100
# mean AUC on test set: 0.47	max AUC on test set so far: 0.59
# Iteration 77/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.59
# Iteration 78/100
# mean AUC on test set: 0.46	max AUC on test set so far: 0.59
# Iteration 79/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.59
# Iteration 80/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.59
# Iteration 81/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.62
# Iteration 82/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.62
# Iteration 83/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.62
# Iteration 84/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.62
# Iteration 85/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.62
# Iteration 86/100
# mean AUC on test set: 0.47	max AUC on test set so far: 0.62
# Iteration 87/100
# mean AUC on test set: 0.53	max AUC on test set so far: 0.62
# Iteration 88/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.62
# Iteration 89/100
# mean AUC on test set: 0.47	max AUC on test set so far: 0.62
# Iteration 90/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.62
# Iteration 91/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.62
# Iteration 92/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.62
# Iteration 93/100
# mean AUC on test set: 0.47	max AUC on test set so far: 0.62
# Iteration 94/100
# mean AUC on test set: 0.53	max AUC on test set so far: 0.62
# Iteration 95/100
# mean AUC on test set: 0.47	max AUC on test set so far: 0.62
# Iteration 96/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.62
# Iteration 97/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.62
# Iteration 98/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.62
# Iteration 99/100
# mean AUC on test set: 0.47	max AUC on test set so far: 0.62
# Iteration 100/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.62
# mean AUC Train: 0.71 (+- 0.01)	Test: 0.50 (+- 0.02)
# mean ACC Train: 0.64 (+- 0.01)	Test: 0.63 (+- 0.01)

# %%
a, b = testing_routine(BAYES_model, AA, FF, verbose=True)
ROC_curve(a,b)
# Out:
# Iteration 1/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.53
# Iteration 2/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.55
# Iteration 3/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.55
# Iteration 4/100
# mean AUC on test set: 0.53	max AUC on test set so far: 0.60
# Iteration 5/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.60
# Iteration 6/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.60
# Iteration 7/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.60
# Iteration 8/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.60
# Iteration 9/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.60
# Iteration 10/100
# mean AUC on test set: 0.53	max AUC on test set so far: 0.60
# Iteration 11/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.60
# Iteration 12/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.60
# Iteration 13/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.60
# Iteration 14/100
# mean AUC on test set: 0.53	max AUC on test set so far: 0.60
# Iteration 15/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.60
# Iteration 16/100
# mean AUC on test set: 0.53	max AUC on test set so far: 0.60
# Iteration 17/100
# mean AUC on test set: 0.46	max AUC on test set so far: 0.60
# Iteration 18/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.60
# Iteration 19/100
# mean AUC on test set: 0.53	max AUC on test set so far: 0.60
# Iteration 20/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.60
# Iteration 21/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.60
# Iteration 22/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.60
# Iteration 23/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.60
# Iteration 24/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.60
# Iteration 25/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.60
# Iteration 26/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.60
# Iteration 27/100
# mean AUC on test set: 0.53	max AUC on test set so far: 0.60
# Iteration 28/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.60
# Iteration 29/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.60
# Iteration 30/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.60
# Iteration 31/100
# mean AUC on test set: 0.47	max AUC on test set so far: 0.60
# Iteration 32/100
# mean AUC on test set: 0.57	max AUC on test set so far: 0.61
# Iteration 33/100
# mean AUC on test set: 0.53	max AUC on test set so far: 0.61
# Iteration 34/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.61
# Iteration 35/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.61
# Iteration 36/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.61
# Iteration 37/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.61
# Iteration 38/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.61
# Iteration 39/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.61
# Iteration 40/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.61
# Iteration 41/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.61
# Iteration 42/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.61
# Iteration 43/100
# mean AUC on test set: 0.53	max AUC on test set so far: 0.61
# Iteration 44/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.61
# Iteration 45/100
# mean AUC on test set: 0.54	max AUC on test set so far: 0.61
# Iteration 46/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.63
# Iteration 47/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.63
# Iteration 48/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.63
# Iteration 49/100
# mean AUC on test set: 0.47	max AUC on test set so far: 0.63
# Iteration 50/100
# mean AUC on test set: 0.46	max AUC on test set so far: 0.63
# Iteration 51/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.63
# Iteration 52/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.63
# Iteration 53/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.63
# Iteration 54/100
# mean AUC on test set: 0.46	max AUC on test set so far: 0.63
# Iteration 55/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.63
# Iteration 56/100
# mean AUC on test set: 0.47	max AUC on test set so far: 0.63
# Iteration 57/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.63
# Iteration 58/100
# mean AUC on test set: 0.47	max AUC on test set so far: 0.63
# Iteration 59/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.63
# Iteration 60/100
# mean AUC on test set: 0.53	max AUC on test set so far: 0.63
# Iteration 61/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.63
# Iteration 62/100
# mean AUC on test set: 0.53	max AUC on test set so far: 0.63
# Iteration 63/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.63
# Iteration 64/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.63
# Iteration 65/100
# mean AUC on test set: 0.53	max AUC on test set so far: 0.63
# Iteration 66/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.63
# Iteration 67/100
# mean AUC on test set: 0.56	max AUC on test set so far: 0.63
# Iteration 68/100
# mean AUC on test set: 0.54	max AUC on test set so far: 0.63
# Iteration 69/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.63
# Iteration 70/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.63
# Iteration 71/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.63
# Iteration 72/100
# mean AUC on test set: 0.46	max AUC on test set so far: 0.63
# Iteration 73/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.63
# Iteration 74/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.63
# Iteration 75/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.63
# Iteration 76/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.63
# Iteration 77/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.63
# Iteration 78/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.63
# Iteration 79/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.63
# Iteration 80/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.63
# Iteration 81/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.63
# Iteration 82/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.63
# Iteration 83/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.63
# Iteration 84/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.63
# Iteration 85/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.63
# Iteration 86/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.63
# Iteration 87/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.63
# Iteration 88/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.63
# Iteration 89/100
# mean AUC on test set: 0.53	max AUC on test set so far: 0.63
# Iteration 90/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.63
# Iteration 91/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.63
# Iteration 92/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.63
# Iteration 93/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.63
# Iteration 94/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.63
# Iteration 95/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.63
# Iteration 96/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.63
# Iteration 97/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.63
# Iteration 98/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.63
# Iteration 99/100
# mean AUC on test set: 0.47	max AUC on test set so far: 0.63
# Iteration 100/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.63
# mean AUC Train: 0.77 (+- 0.01)	Test: 0.51 (+- 0.02)
# mean ACC Train: 0.99 (+- 0.00)	Test: 0.99 (+- 0.00)

# %%
a, b = testing_routine(SVM_model, AA, FF, verbose=True)
ROC_curve(a,b)
# Out:
# Iteration 1/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.53
# Iteration 2/100
# mean AUC on test set: 0.46	max AUC on test set so far: 0.53
# Iteration 3/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.57
# Iteration 4/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.57
# Iteration 5/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.57
# Iteration 6/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.57
# Iteration 7/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.57
# Iteration 8/100
# mean AUC on test set: 0.46	max AUC on test set so far: 0.57
# Iteration 9/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.57
# Iteration 10/100
# mean AUC on test set: 0.46	max AUC on test set so far: 0.57
# Iteration 11/100
# mean AUC on test set: 0.45	max AUC on test set so far: 0.57
# Iteration 12/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.57
# Iteration 13/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.57
# Iteration 14/100
# mean AUC on test set: 0.47	max AUC on test set so far: 0.57
# Iteration 15/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.57
# Iteration 16/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.57
# Iteration 17/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.57
# Iteration 18/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.57
# Iteration 19/100
# mean AUC on test set: 0.47	max AUC on test set so far: 0.57
# Iteration 20/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.57
# Iteration 21/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.57
# Iteration 22/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.57
# Iteration 23/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.57
# Iteration 24/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.57
# Iteration 25/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.57
# Iteration 26/100
# mean AUC on test set: 0.44	max AUC on test set so far: 0.57
# Iteration 27/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.57
# Iteration 28/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.57
# Iteration 29/100
# mean AUC on test set: 0.47	max AUC on test set so far: 0.57
# Iteration 30/100
# mean AUC on test set: 0.46	max AUC on test set so far: 0.57
# Iteration 31/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.57
# Iteration 32/100
# mean AUC on test set: 0.47	max AUC on test set so far: 0.57
# Iteration 33/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.57
# Iteration 34/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.57
# Iteration 35/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.57
# Iteration 36/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.57
# Iteration 37/100
# mean AUC on test set: 0.44	max AUC on test set so far: 0.57
# Iteration 38/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.57
# Iteration 39/100
# mean AUC on test set: 0.43	max AUC on test set so far: 0.57
# Iteration 40/100
# mean AUC on test set: 0.45	max AUC on test set so far: 0.57
# Iteration 41/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.57
# Iteration 42/100
# mean AUC on test set: 0.45	max AUC on test set so far: 0.57
# Iteration 43/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.57
# Iteration 44/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.57
# Iteration 45/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.57
# Iteration 46/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.58
# Iteration 47/100
# mean AUC on test set: 0.46	max AUC on test set so far: 0.58
# Iteration 48/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.58
# Iteration 49/100
# mean AUC on test set: 0.47	max AUC on test set so far: 0.58
# Iteration 50/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.58
# Iteration 51/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.58
# Iteration 52/100
# mean AUC on test set: 0.47	max AUC on test set so far: 0.58
# Iteration 53/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.58
# Iteration 54/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.58
# Iteration 55/100
# mean AUC on test set: 0.47	max AUC on test set so far: 0.58
# Iteration 56/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.58
# Iteration 57/100
# mean AUC on test set: 0.54	max AUC on test set so far: 0.58
# Iteration 58/100
# mean AUC on test set: 0.45	max AUC on test set so far: 0.58
# Iteration 59/100
# mean AUC on test set: 0.47	max AUC on test set so far: 0.58
# Iteration 60/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.58
# Iteration 61/100
# mean AUC on test set: 0.54	max AUC on test set so far: 0.58
# Iteration 62/100
# mean AUC on test set: 0.53	max AUC on test set so far: 0.58
# Iteration 63/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.58
# Iteration 64/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.58
# Iteration 65/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.58
# Iteration 66/100
# mean AUC on test set: 0.54	max AUC on test set so far: 0.58
# Iteration 67/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.58
# Iteration 68/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.58
# Iteration 69/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.58
# Iteration 70/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.58
# Iteration 71/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.58
# Iteration 72/100
# mean AUC on test set: 0.53	max AUC on test set so far: 0.58
# Iteration 73/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.58
# Iteration 74/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.58
# Iteration 75/100
# mean AUC on test set: 0.47	max AUC on test set so far: 0.58
# Iteration 76/100
# mean AUC on test set: 0.54	max AUC on test set so far: 0.58
# Iteration 77/100
# mean AUC on test set: 0.47	max AUC on test set so far: 0.59
# Iteration 78/100
# mean AUC on test set: 0.53	max AUC on test set so far: 0.61
# Iteration 79/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.61
# Iteration 80/100
# mean AUC on test set: 0.45	max AUC on test set so far: 0.61
# Iteration 81/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.61
# Iteration 82/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.61
# Iteration 83/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.61
# Iteration 84/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.61
# Iteration 85/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.61
# Iteration 86/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.61
# Iteration 87/100
# mean AUC on test set: 0.51	max AUC on test set so far: 0.61
# Iteration 88/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.61
# Iteration 89/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.61
# Iteration 90/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.61
# Iteration 91/100
# mean AUC on test set: 0.49	max AUC on test set so far: 0.61
# Iteration 92/100
# mean AUC on test set: 0.46	max AUC on test set so far: 0.61
# Iteration 93/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.61
# Iteration 94/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.61
# Iteration 95/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.61
# Iteration 96/100
# mean AUC on test set: 0.46	max AUC on test set so far: 0.61
# Iteration 97/100
# mean AUC on test set: 0.52	max AUC on test set so far: 0.61
# Iteration 98/100
# mean AUC on test set: 0.48	max AUC on test set so far: 0.61
# Iteration 99/100
# mean AUC on test set: 0.50	max AUC on test set so far: 0.61
# Iteration 100/100
# mean AUC on test set: 0.47	max AUC on test set so far: 0.61
# mean AUC Train: 1.00 (+- 0.00)	Test: 0.49 (+- 0.02)
# mean ACC Train: 0.99 (+- 0.00)	Test: 0.99 (+- 0.00)
